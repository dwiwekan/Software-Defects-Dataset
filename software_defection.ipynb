# %%
import opendatasets as od
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns',None)

# %%
od.download('https://www.kaggle.com/competitions/playground-series-s3e23/data')
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:Your Kaggle Key:Your Kaggle Key:Downloading playground-series-s3e23.zip to .\playground-series-s3e23
# 100%|██████████| 5.71M/5.71M [00:01<00:00, 3.13MB/s]
# Extracting archive .\playground-series-s3e23/playground-series-s3e23.zip to .\playground-series-s3e23

# %%
#read the data from the csv file
data_train = pd.read_csv('playground-series-s3e23/train.csv')
#read the data from the csv file
data_test = pd.read_csv('playground-series-s3e23/train.csv')

# %%
# Check data train
data_train
# Out:
#             id    loc  v(g)  ev(g)  iv(g)      n        v     l      d      i  \
# 0            0   22.0   3.0    1.0    2.0   60.0   278.63  0.06  19.56  14.25
# 1            1   14.0   2.0    1.0    2.0   32.0   151.27  0.14   7.00  21.11
# 2            2   11.0   2.0    1.0    2.0   45.0   197.65  0.11   8.05  22.76
# 3            3    8.0   1.0    1.0    1.0   23.0    94.01  0.19   5.25  17.86
# 4            4   11.0   2.0    1.0    2.0   17.0    60.94  0.18   5.63  12.44
# ...        ...    ...   ...    ...    ...    ...      ...   ...    ...    ...
# 101758  101758   10.0   2.0    1.0    1.0   28.0   122.98  0.15   6.60  18.63
# 101759  101759   27.0   5.0    4.0    1.0  107.0   559.93  0.06  18.00  34.17
# 101760  101760   26.0   1.0    1.0    1.0   83.0   360.17  0.04  22.75  12.56
# 101761  101761   10.0   2.0    1.0    2.0   43.0   191.76  0.15   6.46  29.53
# 101762  101762  136.0  18.0   18.0    1.0  296.0  1704.57  0.02  44.82  44.08
#
# ...

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101763 entries, 0 to 101762
# Data columns (total 23 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 101763 non-null  int64
#  1   loc                101763 non-null  float64
#  2   v(g)               101763 non-null  float64
#  3   ev(g)              101763 non-null  float64
#  4   iv(g)              101763 non-null  float64
#  5   n                  101763 non-null  float64
#  6   v                  101763 non-null  float64
#  7   l                  101763 non-null  float64
#  8   d                  101763 non-null  float64
#  9   i                  101763 non-null  float64
#  10  e                  101763 non-null  float64
#  11  b                  101763 non-null  float64
#  12  t                  101763 non-null  float64
#  13  lOCode             101763 non-null  int64
#  14  lOComment          101763 non-null  int64
# ...

# %% [markdown]
# As we see here, the number of software defects is normally distributed, there is no null values and the data is clean.

# %%
# Describe data train, make pandas show all columns
pd.set_option('display.max_columns',None)
print(data_train.describe().T)
# Out:
#                       count          mean            std  min       25%  \
# id                 101763.0  50881.000000   29376.592059  0.0  25440.50
# loc                101763.0     37.347160      54.600401  1.0     13.00
# v(g)               101763.0      5.492684       7.900855  1.0      2.00
# ev(g)              101763.0      2.845022       4.631262  1.0      1.00
# iv(g)              101763.0      3.498826       5.534541  1.0      1.00
# n                  101763.0     96.655995     171.147191  0.0     25.00
# v                  101763.0    538.280956    1270.791601  0.0     97.67
# l                  101763.0      0.111634       0.100096  0.0      0.05
# d                  101763.0     13.681881      14.121306  0.0      5.60
# i                  101763.0     27.573007      22.856742  0.0     15.56
# e                  101763.0  20853.589876  190571.405427  0.0    564.73
# b                  101763.0      0.179164       0.421844  0.0      0.03
# ...
